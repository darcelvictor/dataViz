# %%
import mca
import pandas as pd
import seaborn as sb

df = pd.read_csv('students.csv')
df
# Out:
#      Unnamed: 0 school sex  age address famsize Pstatus  Medu  Fedu      Mjob  \
# 0             0     GP   F   18       U     GT3       A     4     4   at_home
# 1             1     GP   F   17       U     GT3       T     1     1   at_home
# 2             2     GP   F   15       U     LE3       T     1     1   at_home
# 3             3     GP   F   15       U     GT3       T     4     2    health
# 4             4     GP   F   16       U     GT3       T     3     3     other
# 5             5     GP   M   16       U     LE3       T     4     3  services
# 6             6     GP   M   16       U     LE3       T     2     2     other
# 7             7     GP   F   17       U     GT3       A     4     4     other
# 8             8    NaN   M   15       U     LE3       A     3     2       NaN
# 9             9     GP   M   15       U     GT3       T     3     4     other
# 10           10     GP   F   15       U     GT3       T     4     4   teacher
# 11           11     GP   F   15       U     GT3       T     2     1  services
# 12           12     GP   M   15       U     LE3       T     4     4    health
# 13           13     GP   M   15       U     GT3       T     4     3   teacher
# 14           14     GP   M   15       U     GT3       A     2     2     other
# 15           15     GP   F   16       U     GT3       T     4     4    health
# 16           16     GP   F   16       U     GT3       T     4     4  services
# 17           17     GP   F   16       U     GT3       T     3     3     other
# 18           18     GP   M   17       U     GT3       T     3     2  services
# 19           19     GP   M   16       U     LE3       T     4     3       NaN
# 20           20     GP   M   15       U     GT3       T     4     3       NaN
# 21           21     GP   M   15       U     GT3       T     4     4       NaN
# 22           22     GP   M   16       U     LE3       T     4     2   teacher
# 23           23     GP   M   16       U     LE3       T     2     2     other
# 24           24     GP   F   15       R     GT3       T     2     4  services
# 25           25     GP   F   16       U     GT3       T     2     2  services
# 26           26     GP   M   15       U     GT3       T     2     2     other
# 27           27     GP   M   15       U     GT3       T     4     2    health
# 28           28     GP   M   16       U     LE3       A     3     4  services
# 29           29     GP   M   16       U     GT3       T     4     4   teacher
# ..          ...    ...  ..  ...     ...     ...     ...   ...   ...       ...
# 365         365     MS   M   18       R     GT3       T     1     3   at_home
# 366         366     MS   M   18       U     LE3       T     4     4   teacher
# 367         367     MS   F   17       R     GT3       T     1     1     other
# 368         368     MS   F   18       U     GT3       T     2     3   at_home
# 369         369     MS   F   18       R     GT3       T     4     4     other
# 370         370     MS   F   19       U     LE3       T     3     2  services
# 371         371     MS   M   18       R     LE3       T     1     2       NaN
# 372         372     MS   F   17       U     GT3       T     2     2       NaN
# 373         373     MS   F   17       R     GT3       T     1     2     other
# 374         374     MS   F   18       R     LE3       T     4     4     other
# 375         375     MS   F   18       R     GT3       T     1     1     other
# 376         376     MS   F   20       U     GT3       T     4     2    health
# 377         377     MS   F   18       R     LE3       T     4     4   teacher
# 378         378     MS   F   18       U     GT3       T     3     3     other
# 379         379     MS   F   17       R     GT3       T     3     1   at_home
# 380         380     MS   M   18       U     GT3       T     4     4   teacher
# 381         381     MS   M   18       R     GT3       T     2     1     other
# 382         382     MS   M   17       U     GT3       T     2     3     other
# 383         383     MS   M   19       R     GT3       T     1     1     other
# 384         384     MS   M   18       R     GT3       T     4     2     other
# 385         385     MS   F   18       R     GT3       T     2     2   at_home
# 386         386     MS   F   18       R     GT3       T     4     4   teacher
# 387         387     MS   F   19       R     GT3       T     2     3  services
# 388         388     MS   F   18       U     LE3       T     3     1   teacher
# 389         389     MS   F   18       U     GT3       T     1     1       NaN
# 390         390     MS   M   20       U     LE3       A     2     2       NaN
# 391         391     MS   M   17       U     LE3       T     3     1  services
# 392         392     MS   M   21       R     GT3       T     1     1     other
# 393         393     MS   M   18       R     LE3       T     3     2  services
# 394         394     MS   M   19       U     LE3       T     1     1     other
#
#     ... famrel freetime goout  Dalc  Walc  health absences  G1  G2  G3
# 0   ...      4        3     4     1     1       3        6   5   6   6
# 1   ...      5        3     3     1     1       3        4   5   5   6
# 2   ...      4        3     2     2     3       3       10   7   8  10
# 3   ...      3        2     2     1     1       5        2  15  14  15
# 4   ...      4        3     2     1     2       5        4   6  10  10
# 5   ...      5        4     2     1     2       5       10  15  15  15
# 6   ...      4        4     4     1     1       3        0  12  12  11
# 7   ...      4        1     4     1     1       1        6   6   5   6
# 8   ...      4        2     2     1     1       1        0  16  18  19
# 9   ...      5        5     1     1     1       5        0  14  15  15
# 10  ...      3        3     3     1     2       2        0  10   8   9
# 11  ...      5        2     2     1     1       4        4  10  12  12
# 12  ...      4        3     3     1     3       5        2  14  14  14
# 13  ...      5        4     3     1     2       3        2  10  10  11
# 14  ...      4        5     2     1     1       3        0  14  16  16
# 15  ...      4        4     4     1     2       2        4  14  14  14
# 16  ...      3        2     3     1     2       2        6  13  14  14
# 17  ...      5        3     2     1     1       4        4   8  10  10
# 18  ...      5        5     5     2     4       5       16   6   5   5
# 19  ...      3        1     3     1     3       5        4   8  10  10
# 20  ...      4        4     1     1     1       1        0  13  14  15
# 21  ...      5        4     2     1     1       5        0  12  15  15
# 22  ...      4        5     1     1     3       5        2  15  15  16
# 23  ...      5        4     4     2     4       5        0  13  13  12
# 24  ...      4        3     2     1     1       5        2  10   9   8
# 25  ...      1        2     2     1     3       5       14   6   9   8
# 26  ...      4        2     2     1     2       5        2  12  12  11
# 27  ...      2        2     4     2     4       1        4  15  16  15
# 28  ...      5        3     3     1     1       5        4  11  11  11
# 29  ...      4        4     5     5     5       5       16  10  12  11
# ..  ...    ...      ...   ...   ...   ...     ...      ...  ..  ..  ..
# 365 ...      3        3     4     2     4       3        4  10  10  10
# 366 ...      4        2     2     2     2       5        0  13  13  13
# 367 ...      5        2     1     1     2       1        0   7   6   0
# 368 ...      5        2     3     1     2       4        0  11  10  10
# 369 ...      3        2     2     4     2       5       10  14  12  11
# 370 ...      3        2     2     1     1       3        4   7   7   9
# 371 ...      4        3     3     2     3       3        3  14  12  12
# 372 ...      3        4     3     1     1       3        8  13  11  11
# 373 ...      3        5     5     1     3       1       14   6   5   5
# 374 ...      5        4     4     1     1       1        0  19  18  19
# 375 ...      4        3     2     1     2       4        2   8   8  10
# 376 ...      5        4     3     1     1       3        4  15  14  15
# 377 ...      5        4     3     3     4       2        4   8   9  10
# 378 ...      4        1     3     1     2       1        0  15  15  15
# 379 ...      4        5     4     2     3       1       17  10  10  10
# 380 ...      3        2     4     1     4       2        4  15  14  14
# 381 ...      4        4     3     1     3       5        5   7   6   7
# 382 ...      4        4     3     1     1       3        2  11  11  10
# 383 ...      4        3     2     1     3       5        0   6   5   0
# 384 ...      5        4     3     4     3       3       14   6   5   5
# 385 ...      5        3     3     1     3       4        2  10   9  10
# 386 ...      4        4     3     2     2       5        7   6   5   6
# 387 ...      5        4     2     1     2       5        0   7   5   0
# 388 ...      4        3     4     1     1       1        0   7   9   8
# 389 ...      1        1     1     1     1       5        0   6   5   0
# 390 ...      5        5     4     4     5       4       11   9   9   9
# 391 ...      2        4     5     3     4       2        3  14  16  16
# 392 ...      5        5     3     3     3       3        3  10   8   7
# 393 ...      4        4     1     3     4       5        0  11  12  10
# 394 ...      3        2     3     3     3       5        5   8   9   9
#
# [395 rows x 34 columns]

# %%
df.describe()
# Out:
#        Unnamed: 0         age        Medu        Fedu  traveltime   studytime  \
# count  395.000000  395.000000  395.000000  395.000000  337.000000  395.000000
# mean   197.000000   16.696203    2.749367    2.521519    1.445104    2.035443
# std    114.170924    1.276043    1.094735    1.088201    0.709700    0.839240
# min      0.000000   15.000000    0.000000    0.000000    1.000000    1.000000
# 25%     98.500000   16.000000    2.000000    2.000000    1.000000    1.000000
# 50%    197.000000   17.000000    3.000000    2.000000    1.000000    2.000000
# 75%    295.500000   18.000000    4.000000    3.000000    2.000000    2.000000
# max    394.000000   22.000000    4.000000    4.000000    4.000000    4.000000
#
#          failures      famrel    freetime       goout        Dalc        Walc  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     0.334177    3.944304    3.235443    3.108861    1.481013    2.291139
# std      0.743651    0.896659    0.998862    1.113278    0.890741    1.287897
# min      0.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      0.000000    4.000000    3.000000    2.000000    1.000000    1.000000
# 50%      0.000000    4.000000    3.000000    3.000000    1.000000    2.000000
# 75%      0.000000    5.000000    4.000000    4.000000    2.000000    3.000000
# max      3.000000    5.000000    5.000000    5.000000    5.000000    5.000000
#
#            health    absences          G1          G2          G3
# count  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.554430    5.708861   10.908861   10.713924   10.415190
# std      1.390303    8.003096    3.319195    3.761505    4.581443
# min      1.000000    0.000000    3.000000    0.000000    0.000000
# 25%      3.000000    0.000000    8.000000    9.000000    8.000000
# 50%      4.000000    4.000000   11.000000   11.000000   11.000000
# 75%      5.000000    8.000000   13.000000   13.000000   14.000000
# max      5.000000   75.000000   19.000000   19.000000   20.000000

# %%
df.isnull().any()
# Out:
# Unnamed: 0    False
# school         True
# sex           False
# age           False
# address       False
# famsize       False
# Pstatus       False
# Medu          False
# Fedu          False
# Mjob           True
# Fjob           True
# reason        False
# guardian       True
# traveltime     True
# studytime     False
# failures      False
# schoolsup     False
# famsup        False
# paid          False
# activities    False
# nursery       False
# higher        False
# internet      False
# romantic      False
# famrel        False
# freetime      False
# goout         False
# Dalc          False
# Walc          False
# health        False
# absences      False
# G1            False
# G2            False
# G3            False
# dtype: bool

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# school         object
# sex            object
# age             int64
# address        object
# famsize        object
# Pstatus        object
# Medu            int64
# Fedu            int64
# Mjob           object
# Fjob           object
# reason         object
# guardian       object
# traveltime    float64
# studytime       int64
# failures        int64
# schoolsup      object
# famsup         object
# paid           object
# activities     object
# nursery        object
# higher         object
# internet       object
# romantic       object
# famrel          int64
# freetime        int64
# goout           int64
# Dalc            int64
# Walc            int64
# health          int64
# absences        int64
# G1              int64
# G2              int64
# G3              int64
# dtype: object

# %%
df.head()
# Out:
#    Unnamed: 0 school sex  age address famsize Pstatus  Medu  Fedu     Mjob  \
# 0           0     GP   F   18       U     GT3       A     4     4  at_home
# 1           1     GP   F   17       U     GT3       T     1     1  at_home
# 2           2     GP   F   15       U     LE3       T     1     1  at_home
# 3           3     GP   F   15       U     GT3       T     4     2   health
# 4           4     GP   F   16       U     GT3       T     3     3    other
#
#   ... famrel freetime goout  Dalc  Walc  health absences  G1  G2  G3
# 0 ...      4        3     4     1     1       3        6   5   6   6
# 1 ...      5        3     3     1     1       3        4   5   5   6
# 2 ...      4        3     2     2     3       3       10   7   8  10
# 3 ...      3        2     2     1     1       5        2  15  14  15
# 4 ...      4        3     2     1     2       5        4   6  10  10
#
# [5 rows x 34 columns]

# %%
df['sex'].value_counts(sort="F").plot.pie()

# %%
df['age'].value_counts().plot.pie()

# %%
sb.heatmap(df[['G1','G2','G3','Medu','Fedu','Dalc','Walc']].corr())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-3683c48071ad> in <module>()
# ----> 1 sb.heatmap(df[['G1','G2','G3','Medu','Fedu','Dalc','Walc','Failure']].corr())
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2724             return self._take(indexer, axis=0)
#    2725         else:
# -> 2726             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2727             return self._take(indexer, axis=1)
#    2728
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1325                 if mask.any():
#    1326                     raise KeyError('{mask} not in index'
# -> 1327                                    .format(mask=objarr[mask]))
#    1328
#    1329                 return com._values_from_object(indexer)
#
# KeyError: "['Failure'] not in index"

# %%
df1=df[['G1','G2','G3']]

# %%
sb.pairplot(df1,hue='G3')
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:140: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:132: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/bandwidths.py:20: RuntimeWarning: invalid value encountered in minimum
#   return np.minimum(np.std(X, axis=0, ddof=1), IQR)
# /anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
df['school'].value_counts().plot.pie()
df['sch']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sch'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-a9a0943eb01e> in <module>()
#       1 df['school'].value_counts().plot.pie()
# ----> 2 df['sch']
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sch'

# %%
df2 = pd.DataFrame (df, columns=['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Mjob', 'Fjob', 'reason', 'guardian', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic'])
df2.head(10)
# Out:
#   school sex  age address famsize Pstatus      Mjob      Fjob      reason  \
# 0     GP   F   18       U     GT3       A   at_home   teacher      course
# 1     GP   F   17       U     GT3       T   at_home     other      course
# 2     GP   F   15       U     LE3       T   at_home       NaN       other
# 3     GP   F   15       U     GT3       T    health  services        home
# 4     GP   F   16       U     GT3       T     other     other        home
# 5     GP   M   16       U     LE3       T  services       NaN  reputation
# 6     GP   M   16       U     LE3       T     other     other        home
# 7     GP   F   17       U     GT3       A     other   teacher        home
# 8    NaN   M   15       U     LE3       A       NaN     other        home
# 9     GP   M   15       U     GT3       T     other     other        home
#
#   guardian schoolsup famsup paid activities nursery higher internet romantic
# 0   mother       yes     no   no         no     yes    yes       no       no
# 1   father        no    yes   no         no      no    yes      yes       no
# 2   mother       yes     no  yes         no     yes    yes      yes       no
# 3   mother        no    yes  yes        yes     yes    yes      yes      yes
# 4   father        no    yes  yes         no     yes    yes       no       no
# 5   mother        no    yes  yes        yes     yes    yes      yes       no
# 6   mother        no     no   no         no     yes    yes      yes       no
# 7   mother       yes    yes   no         no     yes    yes       no       no
# 8   mother        no    yes  yes         no     yes    yes      yes       no
# 9   mother        no    yes  yes        yes     yes    yes      yes       no

# %%
# Out:
# G3                                                                                                                               0  \
# famsize Mjob     Fjob     reason     guardian schoolsup famsup paid activities nursery higher internet romantic school sex age
# GT3     at_home  at_home  course     mother   no        yes    yes  yes        yes     yes    yes      no       GP     F   17    0
#                           home       father   no        yes    no   no         yes     yes    yes      yes      GP     F   17    1
#                                      mother   no        yes    yes  yes        no      yes    no       yes      GP     M   17    0
#                           other      mother   no        yes    yes  no         yes     yes    yes      no       GP     F   18    0
#                  health   reputation mother   no        yes    yes  no         yes     yes    yes      yes      GP     F   17    0
#                  other    course     father   no        yes    no   no         no      yes    yes      no       GP     F   17    0
#                                                                                yes     yes    yes      yes      GP     F   17    0
#                                      mother   no        no     no   no         yes     yes    no       no       GP     M   17    1
#                                                                     yes        yes     yes    no       no       GP     F   18    1
#                                                         yes    no   no         yes     yes    yes      no       GP     F   18    0
#                                                                                                                            16    0
#                                                                     yes        no      yes    no       no       GP     F   18    0
#                                                                yes  no         no      yes    yes      no       GP     F   15    0
#                                                                                yes     yes    no       no       MS     M   18    0
#                                      other    no        yes    no   no         no      no     no       no       GP     F   19    0
#                           home       father   no        yes    yes  no         yes     yes    no       no       GP     F   17    0
#                                      mother   no        no     no   no         yes     yes    no       no       GP     M   17    0
#                                                         yes    yes  no         yes     yes    no       no       GP     F   16    0
#                                               yes       no     no   yes        yes     yes    yes      no       GP     F   16    0
#                                                         yes    yes  yes        yes     yes    yes      no       GP     F   15    0
#                           other      mother   no        no     yes  no         yes     yes    no       no       MS     F   18    0
#                           reputation mother   no        no     no   yes        yes     yes    yes      yes      GP     M   16    0
#                                                         yes    yes  yes        no      yes    yes      no       MS     F   17    0
#                  services course     father   no        no     no   no         yes     no     yes      no       GP     M   17    0
#                                                         yes    yes  no         yes     yes    yes      yes      MS     F   18    0
#                                      mother   no        no     no   no         no      yes    yes      no       GP     F   15    0
#                                                                     yes        yes     yes    yes      no       GP     F   17    0
#                           home       mother   no        no     no   yes        no      yes    yes      yes      GP     F   16    1
#                                                         yes    yes  yes        yes     yes    yes      yes      GP     F   18    1
#                           other      other    no        no     yes  yes        no      yes    yes      no       GP     M   17    0
# ...                                                                                                                             ..
# LE3     services other    home       mother   yes       yes    no   yes        yes     yes    yes      no       GP     M   16    0
#                           other      mother   no        yes    yes  no         yes     yes    no       no       GP     F   17    0
#                           reputation mother   no        no     no   no         yes     yes    no       yes      MS     F   17    0
#                                                         yes    yes  no         yes     yes    no       no       GP     F   17    0
#                                                                     yes        yes     yes    yes      no       GP     M   18    0
#                                      other    no        yes    yes  no         no      yes    yes      yes      GP     F   19    0
#                  services course     father   no        no     no   yes        yes     yes    yes      yes      GP     F   17    0
#                                                                yes  yes        yes     yes    yes      yes      GP     F   17    1
#                                      mother   no        no     no   no         no      yes    yes      no       MS     M   17    0
#                                                         yes    yes  yes        yes     yes    yes      no       GP     F   17    0
#                           home       mother   no        no     yes  yes        yes     yes    yes      no       GP     M   15    0
#                                                         yes    no   no         yes     yes    yes      no       GP     F   18    0
#                                      other    no        no     no   yes        no      yes    no       yes      GP     F   19    1
#                           reputation father   no        yes    no   yes        yes     yes    yes      no       GP     M   16    0
#                                                                yes  no         no      yes    yes      no       GP     M   17    0
#                                               yes       no     no   yes        yes     yes    yes      yes      GP     F   15    0
#         teacher  other    course     mother   no        no     no   yes        yes     yes    yes      no       GP     M   16    0
#                                                                yes  yes        yes     yes    yes      no       GP     M   17    0
#                                                         yes    yes  no         yes     yes    yes      no       GP     M   17    0
#                  services course     mother   no        no     yes  yes        yes     yes    yes      no       GP     M   18    0
#                                                                                                                 MS     F   18    0
#                                                         yes    yes  no         yes     yes    yes      no       MS     F   18    0
#                           home       mother   no        no     no   no         yes     yes    yes      no       GP     M   17    0
#                                                         yes    no   yes        yes     yes    yes      no       GP     M   15    0
#                           other      mother   no        no     yes  no         yes     yes    yes      yes      MS     M   18    0
#                           reputation mother   no        yes    yes  yes        yes     yes    yes      no       GP     F   17    0
#                  teacher  course     mother   no        no     no   yes        yes     yes    yes      no       GP     M   15    0
#                           reputation mother   no        yes    yes  no         yes     yes    yes      no       GP     F   16    0
#                                                                     yes        yes     yes    yes      no       GP     M   18    0
# All                                                                                                                             26
#
# G3                                                                                                                              5  \
# famsize Mjob     Fjob     reason     guardian schoolsup famsup paid activities nursery higher internet romantic school sex age
# GT3     at_home  at_home  course     mother   no        yes    yes  yes        yes     yes    yes      no       GP     F   17   0
#                           home       father   no        yes    no   no         yes     yes    yes      yes      GP     F   17   0
#                                      mother   no        yes    yes  yes        no      yes    no       yes      GP     M   17   0
#                           other      mother   no        yes    yes  no         yes     yes    yes      no       GP     F   18   0
#                  health   reputation mother   no        yes    yes  no         yes     yes    yes      yes      GP     F   17   0
#                  other    course     father   no        yes    no   no         no      yes    yes      no       GP     F   17   0
#                                                                                yes     yes    yes      yes      GP     F   17   0
#                                      mother   no        no     no   no         yes     yes    no       no       GP     M   17   0
#                                                                     yes        yes     yes    no       no       GP     F   18   0
#                                                         yes    no   no         yes     yes    yes      no       GP     F   18   0
#                                                                                                                            16   1
#                                                                     yes        no      yes    no       no       GP     F   18   0
#                                                                yes  no         no      yes    yes      no       GP     F   15   0
#                                                                                yes     yes    no       no       MS     M   18   0
#                                      other    no        yes    no   no         no      no     no       no       GP     F   19   0
#                           home       father   no        yes    yes  no         yes     yes    no       no       GP     F   17   0
#                                      mother   no        no     no   no         yes     yes    no       no       GP     M   17   0
#                                                         yes    yes  no         yes     yes    no       no       GP     F   16   0
#                                               yes       no     no   yes        yes     yes    yes      no       GP     F   16   0
#                                                         yes    yes  yes        yes     yes    yes      no       GP     F   15   0
#                           other      mother   no        no     yes  no         yes     yes    no       no       MS     F   18   0
#                           reputation mother   no        no     no   yes        yes     yes    yes      yes      GP     M   16   0
#                                                         yes    yes  yes        no      yes    yes      no       MS     F   17   0
#                  services course     father   no        no     no   no         yes     no     yes      no       GP     M   17   0
#                                                         yes    yes  no         yes     yes    yes      yes      MS     F   18   0
#                                      mother   no        no     no   no         no      yes    yes      no       GP     F   15   0
#                                                                     yes        yes     yes    yes      no       GP     F   17   0
#                           home       mother   no        no     no   yes        no      yes    yes      yes      GP     F   16   0
#                                                         yes    yes  yes        yes     yes    yes      yes      GP     F   18   0
#                           other      other    no        no     yes  yes        no      yes    yes      no       GP     M   17   0
# ...                                                                                                                            ..
# LE3     services other    home       mother   yes       yes    no   yes        yes     yes    yes      no       GP     M   16   0
#                           other      mother   no        yes    yes  no         yes     yes    no       no       GP     F   17   0
#                           reputation mother   no        no     no   no         yes     yes    no       yes      MS     F   17   0
#                                                         yes    yes  no         yes     yes    no       no       GP     F   17   0
#                                                                     yes        yes     yes    yes      no       GP     M   18   0
#                                      other    no        yes    yes  no         no      yes    yes      yes      GP     F   19   0
#                  services course     father   no        no     no   yes        yes     yes    yes      yes      GP     F   17   0
#                                                                yes  yes        yes     yes    yes      yes      GP     F   17   0
#                                      mother   no        no     no   no         no      yes    yes      no       MS     M   17   0
#                                                         yes    yes  yes        yes     yes    yes      no       GP     F   17   0
#                           home       mother   no        no     yes  yes        yes     yes    yes      no       GP     M   15   0
#                                                         yes    no   no         yes     yes    yes      no       GP     F   18   0
#                                      other    no        no     no   yes        no      yes    no       yes      GP     F   19   0
#                           reputation father   no        yes    no   yes        yes     yes    yes      no       GP     M   16   0
#                                                                yes  no         no      yes    yes      no       GP     M   17   0
#                                               yes       no     no   yes        yes     yes    yes      yes      GP     F   15   0
#         teacher  other    course     mother   no        no     no   yes        yes     yes    yes      no       GP     M   16   0
#                                                                yes  yes        yes     yes    yes      no       GP     M   17   0
#                                                         yes    yes  no         yes     yes    yes      no       GP     M   17   0
#                  services course     mother   no        no     yes  yes        yes     yes    yes      no       GP     M   18   0
#                                                                                                                 MS     F   18   0
#                                                         yes    yes  no         yes     yes    yes      no       MS     F   18   0
#                           home       mother   no        no     no   no         yes     yes    yes      no       GP     M   17   0
#                                                         yes    no   yes        yes     yes    yes      no       GP     M   15   0
#                           other      mother   no        no     yes  no         yes     yes    yes      yes      MS     M   18   0
#                           reputation mother   no        yes    yes  yes        yes     yes    yes      no       GP     F   17   0
#                  teacher  course     mother   no        no     no   yes        yes     yes    yes      no       GP     M   15   0
#                           reputation mother   no        yes    yes  no         yes     yes    yes      no       GP     F   16   0
#                                                                     yes        yes     yes    yes      no       GP     M   18   0
# All                                                                                                                             7
#
# G3                                                                                                                               6  \
# famsize Mjob     Fjob     reason     guardian schoolsup famsup paid activities nursery higher internet romantic school sex age
# GT3     at_home  at_home  course     mother   no        yes    yes  yes        yes     yes    yes      no       GP     F   17    0
#                           home       father   no        yes    no   no         yes     yes    yes      yes      GP     F   17    0
#                                      mother   no        yes    yes  yes        no      yes    no       yes      GP     M   17    0
#                           other      mother   no        yes    yes  no         yes     yes    yes      no       GP     F   18    0
#                  health   reputation mother   no        yes    yes  no         yes     yes    yes      yes      GP     F   17    0
#                  other    course     father   no        yes    no   no         no      yes    yes      no       GP     F   17    1
#                                                                                yes     yes    yes      yes      GP     F   17    0
#                                      mother   no        no     no   no         yes     yes    no       no       GP     M   17    0
#                                                                     yes        yes     yes    no       no       GP     F   18    0
#                                                         yes    no   no         yes     yes    yes      no       GP     F   18    0
#                                                                                                                            16    0
#                                                                     yes        no      yes    no       no       GP     F   18    0
#                                                                yes  no         no      yes    yes      no       GP     F   15    0
#                                                                                yes     yes    no       no       MS     M   18    0
#                                      other    no        yes    no   no         no      no     no       no       GP     F   19    0
#                           home       father   no        yes    yes  no         yes     yes    no       no       GP     F   17    0
#                                      mother   no        no     no   no         yes     yes    no       no       GP     M   17    0
#                                                         yes    yes  no         yes     yes    no       no       GP     F   16    0
#                                               yes       no     no   yes        yes     yes    yes      no       GP     F   16    0
#                                                         yes    yes  yes        yes     yes    yes      no       GP     F   15    0
#                           other      mother   no        no     yes  no         yes     yes    no       no       MS     F   18    0
#                           reputation mother   no        no     no   yes        yes     yes    yes      yes      GP     M   16    0
#                                                         yes    yes  yes        no      yes    yes      no       MS     F   17    0
#                  services course     father   no        no     no   no         yes     no     yes      no       GP     M   17    0
#                                                         yes    yes  no         yes     yes    yes      yes      MS     F   18    0
#                                      mother   no        no     no   no         no      yes    yes      no       GP     F   15    0
#                                                                     yes        yes     yes    yes      no       GP     F   17    0
#                           home       mother   no        no     no   yes        no      yes    yes      yes      GP     F   16    0
#                                                         yes    yes  yes        yes     yes    yes      yes      GP     F   18    0
#                           other      other    no        no     yes  yes        no      yes    yes      no       GP     M   17    0
# ...                                                                                                                             ..
# LE3     services other    home       mother   yes       yes    no   yes        yes     yes    yes      no       GP     M   16    0
#                           other      mother   no        yes    yes  no         yes     yes    no       no       GP     F   17    0
#                           reputation mother   no        no     no   no         yes     yes    no       yes      MS     F   17    0
#                                                         yes    yes  no         yes     yes    no       no       GP     F   17    0
#                                                                     yes        yes     yes    yes      no       GP     M   18    0
#                                      other    no        yes    yes  no         no      yes    yes      yes      GP     F   19    0
#                  services course     father   no        no     no   yes        yes     yes    yes      yes      GP     F   17    0
#                                                                yes  yes        yes     yes    yes      yes      GP     F   17    0
#                                      mother   no        no     no   no         no      yes    yes      no       MS     M   17    0
#                                                         yes    yes  yes        yes     yes    yes      no       GP     F   17    0
#                           home       mother   no        no     yes  yes        yes     yes    yes      no       GP     M   15    0
#                                                         yes    no   no         yes     yes    yes      no       GP     F   18    0
#                                      other    no        no     no   yes        no      yes    no       yes      GP     F   19    0
#                           reputation father   no        yes    no   yes        yes     yes    yes      no       GP     M   16    0
#                                                                yes  no         no      yes    yes      no       GP     M   17    0
#                                               yes       no     no   yes        yes     yes    yes      yes      GP     F   15    0
#         teacher  other    course     mother   no        no     no   yes        yes     yes    yes      no       GP     M   16    0
#                                                                yes  yes        yes     yes    yes      no       GP     M   17    0
#                                                         yes    yes  no         yes     yes    yes      no       GP     M   17    0
#                  services course     mother   no        no     yes  yes        yes     yes    yes      no       GP     M   18    0
#                                                                                                                 MS     F   18    0
#                                                         yes    yes  no         yes     yes    yes      no       MS     F   18    0
#                           home       mother   no        no     no   no         yes     yes    yes      no       GP     M   17    0
#                                                         yes    no   yes        yes     yes    yes      no       GP     M   15    0
#                           other      mother   no        no     yes  no         yes     yes    yes      yes      MS     M   18    0
#                           reputation mother   no        yes    yes  yes        yes     yes    yes      no       GP     F   17    0
#                  teacher  course     mother   no        no     no   yes        yes     yes    yes      no       GP     M   15    0
#                           reputation mother   no        yes    yes  no         yes     yes    yes      no       GP     F   16    0
#                                                                     yes        yes     yes    yes      no       GP     M   18    0
# All                                                                                                                             10
#
# G3                                                                                                                              7  \
# famsize Mjob     Fjob     reason     guardian schoolsup famsup paid activities nursery higher internet romantic school sex age
# GT3     at_home  at_home  course     mother   no        yes    yes  yes        yes     yes    yes      no       GP     F   17   0
#                           home       father   no        yes    no   no         yes     yes    yes      yes      GP     F   17   0
#                                      mother   no        yes    yes  yes        no      yes    no       yes      GP     M   17   0
#                           other      mother   no        yes    yes  no         yes     yes    yes      no       GP     F   18   0
#                  health   reputation mother   no        yes    yes  no         yes     yes    yes      yes      GP     F   17   0
#                  other    course     father   no        yes    no   no         no      yes    yes      no       GP     F   17   0
#                                                                                yes     yes    yes      yes      GP     F   17   0
#                                      mother   no        no     no   no         yes     yes    no       no       GP     M   17   0
#                                                                     yes        yes     yes    no       no       GP     F   18   0
#                                                         yes    no   no         yes     yes    yes      no       GP     F   18   0
#                                                                                                                            16   0
#                                                                     yes        no      yes    no       no       GP     F   18   0
#                                                                yes  no         no      yes    yes      no       GP     F   15   0
#                                                                                yes     yes    no       no       MS     M   18   0
#                                      other    no        yes    no   no         no      no     no       no       GP     F   19   0
#                           home       father   no        yes    yes  no         yes     yes    no       no       GP     F   17   0
#                                      mother   no        no     no   no         yes     yes    no       no       GP     M   17   0
#                                                         yes    yes  no         yes     yes    no       no       GP     F   16   0
#                                               yes       no     no   yes        yes     yes    yes      no       GP     F   16   0
#                                                         yes    yes  yes        yes     yes    yes      no       GP     F   15   0
#                           other      mother   no        no     yes  no         yes     yes    no       no       MS     F   18   0
#                           reputation mother   no        no     no   yes        yes     yes    yes      yes      GP     M   16   0
#                                                         yes    yes  yes        no      yes    yes      no       MS     F   17   0
#                  services course     father   no        no     no   no         yes     no     yes      no       GP     M   17   0
#                                                         yes    yes  no         yes     yes    yes      yes      MS     F   18   0
#                                      mother   no        no     no   no         no      yes    yes      no       GP     F   15   0
#                                                                     yes        yes     yes    yes      no       GP     F   17   0
#                           home       mother   no        no     no   yes        no      yes    yes      yes      GP     F   16   0
#                                                         yes    yes  yes        yes     yes    yes      yes      GP     F   18   0
#                           other      other    no        no     yes  yes        no      yes    yes      no       GP     M   17   0
# ...                                                                                                                            ..
# LE3     services other    home       mother   yes       yes    no   yes        yes     yes    yes      no       GP     M   16   0
#                           other      mother   no        yes    yes  no         yes     yes    no       no       GP     F   17   0
#                           reputation mother   no        no     no   no         yes     yes    no       yes      MS     F   17   0
#                                                         yes    yes  no         yes     yes    no       no       GP     F   17   0
#                                                                     yes        yes     yes    yes      no       GP     M   18   0
#                                      other    no        yes    yes  no         no      yes    yes      yes      GP     F   19   0
#                  services course     father   no        no     no   yes        yes     yes    yes      yes      GP     F   17   0
#                                                                yes  yes        yes     yes    yes      yes      GP     F   17   0
#                                      mother   no        no     no   no         no      yes    yes      no       MS     M   17   0
#                                                         yes    yes  yes        yes     yes    yes      no       GP     F   17   0
#                           home       mother   no        no     yes  yes        yes     yes    yes      no       GP     M   15   0
#                                                         yes    no   no         yes     yes    yes      no       GP     F   18   0
#                                      other    no        no     no   yes        no      yes    no       yes      GP     F   19   0
#                           reputation father   no        yes    no   yes        yes     yes    yes      no       GP     M   16   0
#                                                                yes  no         no      yes    yes      no       GP     M   17   0
#                                               yes       no     no   yes        yes     yes    yes      yes      GP     F   15   0
#         teacher  other    course     mother   no        no     no   yes        yes     yes    yes      no       GP     M   16   0
#                                                                yes  yes        yes     yes    yes      no       GP     M   17   0
#                                                         yes    yes  no         yes     yes    yes      no       GP     M   17   0
#                  services course     mother   no        no     yes  yes        yes     yes    yes      no       GP     M   18   0
#                                                                                                                 MS     F   18   0
#                                                         yes    yes  no         yes     yes    yes      no       MS     F   18   0
#                           home       mother   no        no     no   no         yes     yes    yes      no       GP     M   17   0
#                                                         yes    no   yes        yes     yes    yes      no       GP     M   15   0
#                           other      mother   no        no     yes  no         yes     yes    yes      yes      MS     M   18   0
#                           reputation mother   no        yes    yes  yes        yes     yes    yes      no       GP     F   17   0
#                  teacher  course     mother   no        no     no   yes        yes     yes    yes      no       GP     M   15   0
#                           reputation mother   no        yes    yes  no         yes     yes    yes      no       GP     F   16   0
#                                                                     yes        yes     yes    yes      no       GP     M   18   0
# All                                                                                                                             5
#
# G3                                                                                                                               8  \
# famsize Mjob     Fjob     reason     guardian schoolsup famsup paid activities nursery higher internet romantic school sex age
# GT3     at_home  at_home  course     mother   no        yes    yes  yes        yes     yes    yes      no       GP     F   17    0
#                           home       father   no        yes    no   no         yes     yes    yes      yes      GP     F   17    0
#                                      mother   no        yes    yes  yes        no      yes    no       yes      GP     M   17    0
#                           other      mother   no        yes    yes  no         yes     yes    yes      no       GP     F   18    0
#                  health   reputation mother   no        yes    yes  no         yes     yes    yes      yes      GP     F   17    0
#                  other    course     father   no        yes    no   no         no      yes    yes      no       GP     F   17    0
#                                                                                yes     yes    yes      yes      GP     F   17    0
#                                      mother   no        no     no   no         yes     yes    no       no       GP     M   17    0
#                                                                     yes        yes     yes    no       no       GP     F   18    0
#                                                         yes    no   no         yes     yes    yes      no       GP     F   18    0
#                                                                                                                            16    0
#                                                                     yes        no      yes    no       no       GP     F   18    0
#                                                                yes  no         no      yes    yes      no       GP     F   15    0
#                                                                                yes     yes    no       no       MS     M   18    0
#                                      other    no        yes    no   no         no      no     no       no       GP     F   19    0
#                           home       father   no        yes    yes  no         yes     yes    no       no       GP     F   17    1
#                                      mother   no        no     no   no         yes     yes    no       no       GP     M   17    0
#                                                         yes    yes  no         yes     yes    no       no       GP     F   16    0
#                                               yes       no     no   yes        yes     yes    yes      no       GP     F   16    0
#                                                         yes    yes  yes        yes     yes    yes      no       GP     F   15    0
#                           other      mother   no        no     yes  no         yes     yes    no       no       MS     F   18    0
#                           reputation mother   no        no     no   yes        yes     yes    yes      yes      GP     M   16    0
#                                                         yes    yes  yes        no      yes    yes      no       MS     F   17    0
#                  services course     father   no        no     no   no         yes     no     yes      no       GP     M   17    0
#                                                         yes    yes  no         yes     yes    yes      yes      MS     F   18    0
#                                      mother   no        no     no   no         no      yes    yes      no       GP     F   15    0
#                                                                     yes        yes     yes    yes      no       GP     F   17    0
#                           home       mother   no        no     no   yes        no      yes    yes      yes      GP     F   16    0
#                                                         yes    yes  yes        yes     yes    yes      yes      GP     F   18    0
#                           other      other    no        no     yes  yes        no      yes    yes      no       GP     M   17    1
# ...                                                                                                                             ..
# LE3     services other    home       mother   yes       yes    no   yes        yes     yes    yes      no       GP     M   16    0
#                           other      mother   no        yes    yes  no         yes     yes    no       no       GP     F   17    0
#                           reputation mother   no        no     no   no         yes     yes    no       yes      MS     F   17    0
#                                                         yes    yes  no         yes     yes    no       no       GP     F   17    0
#                                                                     yes        yes     yes    yes      no       GP     M   18    0
#                                      other    no        yes    yes  no         no      yes    yes      yes      GP     F   19    0
#                  services course     father   no        no     no   yes        yes     yes    yes      yes      GP     F   17    0
#                                                                yes  yes        yes     yes    yes      yes      GP     F   17    0
#                                      mother   no        no     no   no         no      yes    yes      no       MS     M   17    0
#                                                         yes    yes  yes        yes     yes    yes      no       GP     F   17    0
#                           home       mother   no        no     yes  yes        yes     yes    yes      no       GP     M   15    0
#                                                         yes    no   no         yes     yes    yes      no       GP     F   18    0
#                                      other    no        no     no   yes        no      yes    no       yes      GP     F   19    0
#                           reputation father   no        yes    no   yes        yes     yes    yes      no       GP     M   16    0
#                                                                yes  no         no      yes    yes      no       GP     M   17    0
#                                               yes       no     no   yes        yes     yes    yes      yes      GP     F   15    0
#         teacher  other    course     mother   no        no     no   yes        yes     yes    yes      no       GP     M   16    0
#                                                                yes  yes        yes     yes    yes      no       GP     M   17    0
#                                                         yes    yes  no         yes     yes    yes      no       GP     M   17    0
#                  services course     mother   no        no     yes  yes        yes     yes    yes      no       GP     M   18    0
#                                                                                                                 MS     F   18    0
#                                                         yes    yes  no         yes     yes    yes      no       MS     F   18    1
#                           home       mother   no        no     no   no         yes     yes    yes      no       GP     M   17    0
#                                                         yes    no   yes        yes     yes    yes      no       GP     M   15    0
#                           other      mother   no        no     yes  no         yes     yes    yes      yes      MS     M   18    0
#                           reputation mother   no        yes    yes  yes        yes     yes    yes      no       GP     F   17    0
#                  teacher  course     mother   no        no     no   yes        yes     yes    yes      no       GP     M   15    0
#                           reputation mother   no        yes    yes  no         yes     yes    yes      no       GP     F   16    0
#                                                                     yes        yes     yes    yes      no       GP     M   18    0
# All                                                                                                                             23
#
# G3                                                                                                                               9  \
# famsize Mjob     Fjob     reason     guardian schoolsup famsup paid activities nursery higher internet romantic school sex age
# GT3     at_home  at_home  course     mother   no        yes    yes  yes        yes     yes    yes      no       GP     F   17    0
#                           home       father   no        yes    no   no         yes     yes    yes      yes      GP     F   17    0
#                                      mother   no        yes    yes  yes        no      yes    no       yes      GP     M   17    0
#                           other      mother   no        yes    yes  no         yes     yes    yes      no       GP     F   18    0
#                  health   reputation mother   no        yes    yes  no         yes     yes    yes      yes      GP     F   17    0
#                  other    course     father   no        yes    no   no         no      yes    yes      no       GP     F   17    0
#                                                                                yes     yes    yes      yes      GP     F   17    0
#                                      mother   no        no     no   no         yes     yes    no       no       GP     M   17    0
#                                                                     yes        yes     yes    no       no       GP     F   18    0
#                                                         yes    no   no         yes     yes    yes      no       GP     F   18    0
#                                                                                                                            16    0
#                                                                     yes        no      yes    no       no       GP     F   18    0
#                                                                yes  no         no      yes    yes      no       GP     F   15    0
#                                                                                yes     yes    no       no       MS     M   18    0
#                                      other    no        yes    no   no         no      no     no       no       GP     F   19    1
#                           home       father   no        yes    yes  no         yes     yes    no       no       GP     F   17    0
#                                      mother   no        no     no   no         yes     yes    no       no       GP     M   17    0
#                                                         yes    yes  no         yes     yes    no       no       GP     F   16    0
#                                               yes       no     no   yes        yes     yes    yes      no       GP     F   16    0
#                                                         yes    yes  yes        yes     yes    yes      no       GP     F   15    0
#                           other      mother   no        no     yes  no         yes     yes    no       no       MS     F   18    0
#                           reputation mother   no        no     no   yes        yes     yes    yes      yes      GP     M   16    0
#                                                         yes    yes  yes        no      yes    yes      no       MS     F   17    0
#                  services course     father   no        no     no   no         yes     no     yes      no       GP     M   17    0
#                                                         yes    yes  no         yes     yes    yes      yes      MS     F   18    0
#                                      mother   no        no     no   no         no      yes    yes      no       GP     F   15    0
#                                                                     yes        yes     yes    yes      no       GP     F   17    1
#                           home       mother   no        no     no   yes        no      yes    yes      yes      GP     F   16    0
#                                                         yes    yes  yes        yes     yes    yes      yes      GP     F   18    0
#                           other      other    no        no     yes  yes        no      yes    yes      no       GP     M   17    0
# ...                                                                                                                             ..
# LE3     services other    home       mother   yes       yes    no   yes        yes     yes    yes      no       GP     M   16    0
#                           other      mother   no        yes    yes  no         yes     yes    no       no       GP     F   17    0
#                           reputation mother   no        no     no   no         yes     yes    no       yes      MS     F   17    0
#                                                         yes    yes  no         yes     yes    no       no       GP     F   17    0
#                                                                     yes        yes     yes    yes      no       GP     M   18    0
#                                      other    no        yes    yes  no         no      yes    yes      yes      GP     F   19    0
#                  services course     father   no        no     no   yes        yes     yes    yes      yes      GP     F   17    0
#                                                                yes  yes        yes     yes    yes      yes      GP     F   17    0
#                                      mother   no        no     no   no         no      yes    yes      no       MS     M   17    0
#                                                         yes    yes  yes        yes     yes    yes      no       GP     F   17    0
#                           home       mother   no        no     yes  yes        yes     yes    yes      no       GP     M   15    0
# ...
#                  other    course     father   no        yes    no   no         no      yes    yes      no       GP     F   17    0
#                                                                                yes     yes    yes      yes      GP     F   17    0
#                                      mother   no        no     no   no         yes     yes    no       no       GP     M   17    0
#                                                                     yes        yes     yes    no       no       GP     F   18    0
#                                                         yes    no   no         yes     yes    yes      no       GP     F   18    0
#                                                                                                                            16    0
#                                                                     yes        no      yes    no       no       GP     F   18    0
#                                                                yes  no         no      yes    yes      no       GP     F   15    0
#                                                                                yes     yes    no       no       MS     M   18    0
#                                      other    no        yes    no   no         no      no     no       no       GP     F   19    0
#                           home       father   no        yes    yes  no         yes     yes    no       no       GP     F   17    0
#                                      mother   no        no     no   no         yes     yes    no       no       GP     M   17    0
#                                                         yes    yes  no         yes     yes    no       no       GP     F   16    0
#                                               yes       no     no   yes        yes     yes    yes      no       GP     F   16    0
#                                                         yes    yes  yes        yes     yes    yes      no       GP     F   15    0
#                           other      mother   no        no     yes  no         yes     yes    no       no       MS     F   18    0
#                           reputation mother   no        no     no   yes        yes     yes    yes      yes      GP     M   16    0
#                                                         yes    yes  yes        no      yes    yes      no       MS     F   17    0
#                  services course     father   no        no     no   no         yes     no     yes      no       GP     M   17    0
#                                                         yes    yes  no         yes     yes    yes      yes      MS     F   18    0
#                                      mother   no        no     no   no         no      yes    yes      no       GP     F   15    0
#                                                                     yes        yes     yes    yes      no       GP     F   17    0
#                           home       mother   no        no     no   yes        no      yes    yes      yes      GP     F   16    0
#                                                         yes    yes  yes        yes     yes    yes      yes      GP     F   18    0
#                           other      other    no        no     yes  yes        no      yes    yes      no       GP     M   17    0
# ...                                                                                                                             ..
# LE3     services other    home       mother   yes       yes    no   yes        yes     yes    yes      no       GP     M   16    0
#                           other      mother   no        yes    yes  no         yes     yes    no       no       GP     F   17    0
#                           reputation mother   no        no     no   no         yes     yes    no       yes      MS     F   17    0
#                                                         yes    yes  no         yes     yes    no       no       GP     F   17    0
#                                                                     yes        yes     yes    yes      no       GP     M   18    0
#                                      other    no        yes    yes  no         no      yes    yes      yes      GP     F   19    0
#                  services course     father   no        no     no   yes        yes     yes    yes      yes      GP     F   17    0
#                                                                yes  yes        yes     yes    yes      yes      GP     F   17    0
#                                      mother   no        no     no   no         no      yes    yes      no       MS     M   17    0
#                                                         yes    yes  yes        yes     yes    yes      no       GP     F   17    0
#                           home       mother   no        no     yes  yes        yes     yes    yes      no       GP     M   15    0
#                                                         yes    no   no         yes     yes    yes      no       GP     F   18    0
#                                      other    no        no     no   yes        no      yes    no       yes      GP     F   19    0
#                           reputation father   no        yes    no   yes        yes     yes    yes      no       GP     M   16    0
#                                                                yes  no         no      yes    yes      no       GP     M   17    0
#                                               yes       no     no   yes        yes     yes    yes      yes      GP     F   15    0
#         teacher  other    course     mother   no        no     no   yes        yes     yes    yes      no       GP     M   16    0
#                                                                yes  yes        yes     yes    yes      no       GP     M   17    0
#                                                         yes    yes  no         yes     yes    yes      no       GP     M   17    0
#                  services course     mother   no        no     yes  yes        yes     yes    yes      no       GP     M   18    0
#                                                                                                                 MS     F   18    0
#                                                         yes    yes  no         yes     yes    yes      no       MS     F   18    0
#                           home       mother   no        no     no   no         yes     yes    yes      no       GP     M   17    0
#                                                         yes    no   yes        yes     yes    yes      no       GP     M   15    0
#                           other      mother   no        no     yes  no         yes     yes    yes      yes      MS     M   18    0
#                           reputation mother   no        yes    yes  yes        yes     yes    yes      no       GP     F   17    0
#                  teacher  course     mother   no        no     no   yes        yes     yes    yes      no       GP     M   15    0
#                           reputation mother   no        yes    yes  no         yes     yes    yes      no       GP     F   16    0
#                                                                     yes        yes     yes    yes      no       GP     M   18    0
# All                                                                                                                              1
#
# G3                                                                                                                              All
# famsize Mjob     Fjob     reason     guardian schoolsup famsup paid activities nursery higher internet romantic school sex age
# GT3     at_home  at_home  course     mother   no        yes    yes  yes        yes     yes    yes      no       GP     F   17     1
#                           home       father   no        yes    no   no         yes     yes    yes      yes      GP     F   17     1
#                                      mother   no        yes    yes  yes        no      yes    no       yes      GP     M   17     1
#                           other      mother   no        yes    yes  no         yes     yes    yes      no       GP     F   18     1
#                  health   reputation mother   no        yes    yes  no         yes     yes    yes      yes      GP     F   17     1
#                  other    course     father   no        yes    no   no         no      yes    yes      no       GP     F   17     1
#                                                                                yes     yes    yes      yes      GP     F   17     1
#                                      mother   no        no     no   no         yes     yes    no       no       GP     M   17     1
#                                                                     yes        yes     yes    no       no       GP     F   18     1
#                                                         yes    no   no         yes     yes    yes      no       GP     F   18     1
#                                                                                                                            16     1
#                                                                     yes        no      yes    no       no       GP     F   18     1
#                                                                yes  no         no      yes    yes      no       GP     F   15     1
#                                                                                yes     yes    no       no       MS     M   18     1
#                                      other    no        yes    no   no         no      no     no       no       GP     F   19     1
#                           home       father   no        yes    yes  no         yes     yes    no       no       GP     F   17     1
#                                      mother   no        no     no   no         yes     yes    no       no       GP     M   17     1
#                                                         yes    yes  no         yes     yes    no       no       GP     F   16     1
#                                               yes       no     no   yes        yes     yes    yes      no       GP     F   16     1
#                                                         yes    yes  yes        yes     yes    yes      no       GP     F   15     1
#                           other      mother   no        no     yes  no         yes     yes    no       no       MS     F   18     1
#                           reputation mother   no        no     no   yes        yes     yes    yes      yes      GP     M   16     1
#                                                         yes    yes  yes        no      yes    yes      no       MS     F   17     1
#                  services course     father   no        no     no   no         yes     no     yes      no       GP     M   17     1
#                                                         yes    yes  no         yes     yes    yes      yes      MS     F   18     1
#                                      mother   no        no     no   no         no      yes    yes      no       GP     F   15     1
#                                                                     yes        yes     yes    yes      no       GP     F   17     1
#                           home       mother   no        no     no   yes        no      yes    yes      yes      GP     F   16     1
#                                                         yes    yes  yes        yes     yes    yes      yes      GP     F   18     1
#                           other      other    no        no     yes  yes        no      yes    yes      no       GP     M   17     1
# ...                                                                                                                             ...
# LE3     services other    home       mother   yes       yes    no   yes        yes     yes    yes      no       GP     M   16     1
#                           other      mother   no        yes    yes  no         yes     yes    no       no       GP     F   17     1
#                           reputation mother   no        no     no   no         yes     yes    no       yes      MS     F   17     1
#                                                         yes    yes  no         yes     yes    no       no       GP     F   17     1
#                                                                     yes        yes     yes    yes      no       GP     M   18     1
#                                      other    no        yes    yes  no         no      yes    yes      yes      GP     F   19     1
#                  services course     father   no        no     no   yes        yes     yes    yes      yes      GP     F   17     1
#                                                                yes  yes        yes     yes    yes      yes      GP     F   17     1
#                                      mother   no        no     no   no         no      yes    yes      no       MS     M   17     1
#                                                         yes    yes  yes        yes     yes    yes      no       GP     F   17     1
#                           home       mother   no        no     yes  yes        yes     yes    yes      no       GP     M   15     1
#                                                         yes    no   no         yes     yes    yes      no       GP     F   18     1
#                                      other    no        no     no   yes        no      yes    no       yes      GP     F   19     1
#                           reputation father   no        yes    no   yes        yes     yes    yes      no       GP     M   16     1
#                                                                yes  no         no      yes    yes      no       GP     M   17     1
#                                               yes       no     no   yes        yes     yes    yes      yes      GP     F   15     1
#         teacher  other    course     mother   no        no     no   yes        yes     yes    yes      no       GP     M   16     1
#                                                                yes  yes        yes     yes    yes      no       GP     M   17     1
#                                                         yes    yes  no         yes     yes    yes      no       GP     M   17     1
#                  services course     mother   no        no     yes  yes        yes     yes    yes      no       GP     M   18     1
#                                                                                                                 MS     F   18     1
#                                                         yes    yes  no         yes     yes    yes      no       MS     F   18     1
#                           home       mother   no        no     no   no         yes     yes    yes      no       GP     M   17     1
#                                                         yes    no   yes        yes     yes    yes      no       GP     M   15     1
#                           other      mother   no        no     yes  no         yes     yes    yes      yes      MS     M   18     1
#                           reputation mother   no        yes    yes  yes        yes     yes    yes      no       GP     F   17     1
#                  teacher  course     mother   no        no     no   yes        yes     yes    yes      no       GP     M   15     1
#                           reputation mother   no        yes    yes  no         yes     yes    yes      no       GP     F   16     1
#                                                                     yes        yes     yes    yes      no       GP     M   18     1
# All                                                                                                                             284
#
# [284 rows x 18 columns]
